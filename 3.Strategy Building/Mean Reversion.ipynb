# %%
import numpy as np
import pandas as pd
import datetime as dt
import yfinance as yf
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv('/Users/akash/PycharmProjects/Quant/3.Strategy Building/EFS-02_data_AUDCAD.csv')
df['Date'] = pd.to_datetime(df['Date'])
df
# Out:
#            Date      Open      High       Low     Close  Volume
# 0    2011-12-05  1.041400  1.043600  1.038600  1.041400       0
# 1    2011-12-06  1.042600  1.043500  1.034000  1.042600       0
# 2    2011-12-07  1.033700  1.037500  1.033600  1.034000       0
# 3    2011-12-08  1.037000  1.043100  1.033700  1.037300       0
# 4    2011-12-09  1.040400  1.041100  1.030500  1.040300       0
# ...         ...       ...       ...       ...       ...     ...
# 3203 2024-03-14  0.892454  0.892757  0.888870  0.892454       0
# 3204 2024-03-15  0.890200  0.890520  0.886700  0.890200       0
# 3205 2024-03-18  0.888311  0.889950  0.887700  0.888311       0
# 3206 2024-03-19  0.887501  0.888516  0.882795  0.887501       0
# 3207 2024-03-20  0.885780  0.887550  0.885000  0.885780       0
#
# [3208 rows x 6 columns]

# %%
from statsmodels.tsa.stattools import adfuller

result = adfuller(df['Close'])

t_stat = result[0]
p_value = result[1]
critical = result[4]['5%']

print(t_stat < critical)
print(p_value < 0.05)
# Out:
# False
# False
