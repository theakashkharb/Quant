# %%
import numpy as np
import pandas as pd
import datetime as dt
import yfinance as yf
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
df = yf.download("EURUSD=X",start = '2016-01-01',end ='2026-01-01' , interval="1d",auto_adjust=False,multi_level_index=False)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
df.isna().sum()
df = df[['Adj Close','Volume']]

# %%
df
# Out:
#             Adj Close  Volume
# Date
# 2016-01-01   1.085906       0
# 2016-01-04   1.085399       0
# 2016-01-05   1.082755       0
# 2016-01-06   1.075199       0
# 2016-01-07   1.077900       0
# ...               ...     ...
# 2025-12-24   1.179551       0
# 2025-12-26   1.178536       0
# 2025-12-29   1.177274       0
# 2025-12-30   1.177288       0
# 2025-12-31   1.174729       0
#
# [2602 rows x 2 columns]
