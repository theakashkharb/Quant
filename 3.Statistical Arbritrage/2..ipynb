# %%
import numpy as np
import pandas as pd
import datetime as dt
import yfinance as yf
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import statsmodels.api as sm
import statsmodels.tsa.stattools as ts
from statsmodels.tsa.stattools import adfuller
import warnings
warnings.filterwarnings('ignore')

# %%
tickers = ["GOOG", "GOOGL"]
df = yf.download(tickers, start="2014-01-01", end="2026-01-01",auto_adjust=False,multi_level_index=False)['Adj Close']

df.columns = ['A','B']
df.index = pd.to_datetime(df.index)
# Out:
# [*********************100%***********************]  2 of 2 completed

# %%
window = 90
beta = []
pvalues = []
tstats = []
spreads = [None]*len(df)

for i in range(window),len(df):
    x = df['A'].iloc[i-window:i]
    y = df['B'].iloc[i-window:i]

    # Regression
    y_const = sm.add_constant(y)
    model = sm.OLS(x, y_const).fit()

    beta = model.params[1]
    spread = x - beta * y

    # ADF test
    adf = adfuller(spread)

    # Store
    beta.append(beta)
    pvalues.append(adf[1])
    tstats.append(adf[0])

    # Current spread (out-of-sample point)
    current_spread = df['A'].iloc[i] - beta * df['B'].iloc[i]
    spreads[i] = current_spread
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[85], line 8
#       4 tstats = []
#       5 spreads = [None]*len(df)
#       6
#       7 for i in range(window),len(df):
# ----> 8     x = df['A'].iloc[i-window:i]
#       9     y = df['B'].iloc[i-window:i]
#      10
#      11     # Regression
#
# TypeError: unsupported operand type(s) for -: 'range' and 'int'
